# %%
import pandas as pd
import seaborn as sns
from summarytools import dfSummary

# %%
df = pd.read_csv("final_shop_6modata.csv")

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_86c12 thead>tr>th {
#   text-align: left;
# }
# #T_86c12_row0_col0, #T_86c12_row1_col0, #T_86c12_row2_col0, #T_86c12_row3_col0, #T_86c12_row4_col0, #T_86c12_row5_col0, #T_86c12_row6_col0, #T_86c12_row7_col0, #T_86c12_row8_col0, #T_86c12_row9_col0, #T_86c12_row10_col0, #T_86c12_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_86c12_row0_col1, #T_86c12_row1_col1, #T_86c12_row2_col1, #T_86c12_row3_col1, #T_86c12_row4_col1, #T_86c12_row5_col1, #T_86c12_row6_col1, #T_86c12_row7_col1, #T_86c12_row8_col1, #T_86c12_row9_col1, #T_86c12_row10_col1, #T_86c12_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# ...

# %% [markdown]
# ## missing value

# %% [markdown]
# ## outlier

# %%
df.describe()
# Out:
#          Impressions        Clicks         CTR  Conversions   Conv Rate  \
# count     190.000000    190.000000  190.000000   190.000000  190.000000
# mean    14077.363158   4865.805263    0.272105   505.242105    0.079737
# std     29771.686227  11348.529219    0.107894  1052.202922    0.052859
# min        35.000000      2.000000    0.050000     0.000000    0.000000
# 25%      1065.000000    264.500000    0.192500    24.000000    0.050000
# 50%      4969.000000    930.000000    0.285000    70.500000    0.070000
# 75%     13380.000000   4190.500000    0.360000   428.250000    0.100000
# max    276568.000000  99526.000000    0.470000  7563.000000    0.500000
#
#                Cost         CPC       Revenue    Sale Amount          P&L
# count    190.000000  190.000000    190.000000     190.000000   190.000000
# mean    3344.063158    0.791263   2957.684211   63416.180579  -386.361916
# std     6524.606753    0.403312   5962.413097  125414.656922   903.073776
# ...

# %% [markdown]
# ## inconsistent format

# %% [markdown]
# ## duplicate data

# %%
df.duplicated(keep=False).sum()
# Out:
# 0

# %%
df.Month = df.Month.map({'July':7, 'August':8, 'September':9, 'October':10, 'November':11})

# %%
df.head()
# Out:
#                                    Ad Group  Month  Impressions  Clicks   CTR  \
# 0    Shop - 1:1 - Desk - [shop coupon code]      7        16038    6504  0.41
# 1         Shop - 1:1 - Desk - [shop coupon]      7        36462   14367  0.39
# 2  Shop - 1:1 - Desk - [shop discount code]      7         3635    1458  0.40
# 3     Shop - 1:1 - Desk - [shop promo code]      7        26185   10418  0.40
# 4          Shop - 1:1 - Desk - [shop promo]      7          808     282  0.35
#
#    Conversions  Conv Rate   Cost   CPC  Revenue  Sale Amount      P&L
# 0         1166       0.10   6669  1.03     6402    136770.05 -267.086
# 1         2188       0.09  13746  0.96    13262    283215.21 -483.951
# 2          248       0.09   1606  1.10     1723     39165.46  117.136
# 3         2294       0.12  13278  1.27    13042    284823.48 -235.921
# 4           61       0.15    391  1.39      337      7717.77  -53.604

# %%
df.to_csv("final_shop.csv")
